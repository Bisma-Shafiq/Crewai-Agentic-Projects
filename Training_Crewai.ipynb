# %% [markdown]
# <a href="https://colab.research.google.com/github/Bisma-Shafiq/Crewai-Agentic-Projects/blob/main/Training_Crewai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U crewai crewai-tools
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.5/42.5 kB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 3.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.2/240.2 kB 8.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 39.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 545.9/545.9 kB 23.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 29.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.4/211.4 kB 2.7 MB/s eta 0:00:00
# ...

# %%
import os
from google.colab import userdata
os.environ["GEMINI_API_KEY"] = userdata.get('GOOGLE_API_KEY')
os.environ["MODEL"] = "gemini/gemini-1.5-flash"

# %%
import nest_asyncio   # to run crews
nest_asyncio.apply()

# %%
# !crewai create crew project_train_06
# Out:
# Creating folder project_train_06...
# Cache expired or not found. Fetching provider data from the web...
# ...
# Select a provider to set up:
# 1. openai
# 2. anthropic
# 3. gemini
# 4. nvidia_nim
# 5. groq
# 6. ollama
# 7. watson
# 8. bedrock
# 9. azure
# 10. cerebras
# 11. sambanova
# 12. other
# q. Quit
# Enter the number of your choice or 'q' to quit: 3
# Select a model to use for Gemini:
# 1. gemini/gemini-1.5-flash
# 2. gemini/gemini-1.5-pro
# 3. gemini/gemini-gemma-2-9b-it
# 4. gemini/gemini-gemma-2-27b-it
# q. Quit
# Enter the number of your choice or 'q' to quit: 1
# Enter your GEMINI API key (press Enter to skip): AIzaSyB6uIZyYinHhGxBgbu8SsTMMy45dtTLp2E
# API keys and model saved to .env file
# Selected model: gemini/gemini-1.5-flash
#   - Created project_train_06/.gitignore
#   - Created project_train_06/pyproject.toml
#   - Created project_train_06/README.md
#   - Created project_train_06/knowledge/user_preference.txt
# ...

# %%
# %pwd
# Out:
# '/content'

# %%
# %cd project_train_06
# Out:
# /content/project_train_06

# %%
# !ls
# Out:
# knowledge  pyproject.toml  README.md  src  tests

# %% [markdown]
# # Train crew

# %% [markdown]
# open / /content/project_test_05/src/project_test_05/main.py
# pass current_year in the test, train function.
# you can copy input from kickoff
# after updating your test function will be like
#
# ```python
# def train():
#     """
#     Train the crew for a given number of iterations.
#     """
#     inputs = {
#         "topic": "AI LLMs",
#         'current_year': str(datetime.now().year)
#     }
#     try:
#         ProjectTrain06().crew().train(n_iterations=int(sys.argv[1]), filename=sys.argv[2], inputs=inputs)
#
#     except Exception as e:
#         raise Exception(f"An error occurred while training the crew: {e}")
#
# ```

# %%
# !crewai train -n 2 -f "mycrew.pkl"
# Out:
# Streaming output truncated to the last 5000 lines.
# grpc-google-iam-v1 ------------------------------ 16.00 KiB/18.80 KiB
# python-dotenv ------------------------------ 16.00 KiB/19.40 KiB
# distro     ------------------------------ 14.92 KiB/19.80 KiB
# types-requests ------------------------------ 20.19 KiB/20.19 KiB
# nodeenv    ------------------------------ 21.79 KiB/21.79 KiB
# build      ------------------------------ 14.94 KiB/22.41 KiB
# importlib-metadata ------------------------------ 25.89 KiB/25.89 KiB
# executing  ------------------------------ 26.08 KiB/26.08 KiB
# referencing ------------------------------ 26.15 KiB/26.15 KiB
# tenacity   ------------------------------ 27.51 KiB/27.51 KiB
# google-cloud-core ------------------------------ 28.66 KiB/28.66 KiB
# langchain-text-splitters ------------------------------ 30.47 KiB/30.47 KiB
# langchain  ------------------------------ 478.52 KiB/987.87 KiB
# jedi       ------------------------------ 621.90 KiB/1.50 MiB
# ...
